# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# **Loaded the CSV file of crop yield**

# %%
df = pd.read_csv("crop_yield_sorted.csv")
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df.nunique()
# Out:
# Crop                  55
# Crop_Year             24
# Season                 6
# State                 30
# Area               13644
# Production         14016
# Annual_Rainfall      634
# Fertilizer         18598
# Pesticide          17405
# Yield              13551
# dtype: int64

# %% [markdown]
# *Sorted the data by year wise and state wise*

# %%
df = df.sort_values(by = ['Crop_Year', 'State'])
df = df.reset_index(drop=True)

# %% [markdown]
# **Extracted the data of UP**

# %%
#dfup is for Uttar Pradesh data , Here w is for Wheat and r for rice
dfup=df[(df['State'] == 'Uttar Pradesh')].reset_index(drop=True)
dfupw=df[(df['State'] == 'Uttar Pradesh') & (df['Crop']=='Wheat')].reset_index(drop=True)
dfupr= df[((df['State'] == 'Uttar Pradesh') & (df['Crop']=='Rice'))].reset_index(drop=True)
x1 = dfupw['Crop_Year']
x2 = dfupr['Crop_Year']
y1 = dfupw['Fertilizer']
y2 = dfupr[dfupr['Season']=='Kharif']
dfupr
# Out:
#     Crop  Crop_Year       Season          State       Area  Production  \
# 0   Rice       1997  Kharif       Uttar Pradesh  5726527.0    12262794
# 1   Rice       1997  Summer       Uttar Pradesh     6607.0       18281
# 2   Rice       1998  Kharif       Uttar Pradesh  5875153.0    11374070
# 3   Rice       1998  Summer       Uttar Pradesh     5629.0       12643
# 4   Rice       1999  Kharif       Uttar Pradesh  6079822.0    13230539
# 5   Rice       1999  Summer       Uttar Pradesh     6052.0       16186
# 6   Rice       2000  Kharif       Uttar Pradesh  5904128.0    11672250
# 7   Rice       2000  Summer       Uttar Pradesh     3023.0        6899
# 8   Rice       2001  Kharif       Uttar Pradesh  6068496.0    12849116
# 9   Rice       2001  Summer       Uttar Pradesh     2829.0        6741
# 10  Rice       2002  Kharif       Uttar Pradesh  5209137.0     9586935
# 11  Rice       2002  Summer       Uttar Pradesh     4292.0        9411
# ...

# %%
print(y2)
# Out:
# Empty DataFrame
# Columns: [Crop, Crop_Year, Season, State, Area, Production, Annual_Rainfall, Fertilizer, Pesticide, Yield]
# Index: []

# %%
# plt.plot(x1, y1, label='Wheat')
# plt.plot(x2, y2, label='Rice')
# plt.title('Year wise fertilizer used for Wheat')
# plt.grid()
# plt.legend()
# plt.show()

# %%
plt.scatter((dfupw['Yield']), (dfupw['Crop_Year']))
plt.xlabel('Crop  Yield')
plt.ylabel('Year')
plt.title('Yield per year of Wheat')
plt.grid()
plt.show()

# %%
dfy = df[df['Yield'] < 7.5]
dfy
# Out:
#                  Crop  Crop_Year       Season           State      Area  \
# 0           Arhar/Tur       1997  Kharif       Andhra Pradesh  313900.0
# 1           Arhar/Tur       1997  Rabi         Andhra Pradesh    3500.0
# 2               Bajra       1997  Kharif       Andhra Pradesh   89400.0
# 3         Castor seed       1997  Kharif       Andhra Pradesh  169600.0
# 4        Cotton(lint)       1997  Kharif       Andhra Pradesh  906300.0
# ...               ...        ...          ...             ...       ...
# 19684            Urad       2020  Kharif          Uttarakhand   12398.0
# 19685            Urad       2020  Summer          Uttarakhand      58.0
# 19686           Wheat       2020  Rabi            Uttarakhand  297189.0
# 19687  other oilseeds       2020  Kharif          Uttarakhand      13.0
# 19688  other oilseeds       2020  Rabi            Uttarakhand      30.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide     Yield
# ...

# %%
plt.hist((dfy['Yield']), bins=100)
plt.xlabel('Yield')
plt.ylabel('Number of Crop')
plt.title('Yield')
plt.grid()
plt.show()

# %%
dfupr = dfup[dfup['Crop']=='Wheat'].reset_index()
dfupr.nunique()
# Out:
# index              23
# Crop                1
# Crop_Year          23
# Season              1
# State               1
# Area               23
# Production         23
# Annual_Rainfall    23
# Fertilizer         23
# Pesticide          23
# Yield              23
# dtype: int64

# %%
plt.plot(dfupr['Annual_Rainfall'], dfupr['Yield'])
plt.title('Rainfall vs yield')
plt.xlabel('Rain Fall')
plt.ylabel('Yield')
plt.show()

# %% [markdown]
# ### there ia no direct co relation between them

# %%
df.tail(40)
# Out:
#                         Crop  Crop_Year       Season        State      Area  \
# 19649                   Urad       2019  Kharif       West Bengal   66846.0
# 19650                   Urad       2019  Rabi         West Bengal    5502.0
# 19651                  Wheat       2019  Rabi         West Bengal  188308.0
# 19652              Arhar/Tur       2020  Kharif       Uttarakhand    3327.0
# 19653                 Barley       2020  Rabi         Uttarakhand   19280.0
# 19654                 Garlic       2020  Whole Year   Uttarakhand    5345.0
# 19655                   Gram       2020  Rabi         Uttarakhand     728.0
# 19656              Groundnut       2020  Kharif       Uttarakhand     617.0
# 19657             Horse-gram       2020  Kharif       Uttarakhand   13149.0
# 19658                  Maize       2020  Kharif       Uttarakhand   19697.0
# 19659                  Maize       2020  Summer       Uttarakhand     198.0
# ...

# %%
df.shape
# Out:
# (19689, 10)

# %%
dfarea = df[df["Area"] < 7_00_000]

# %%
x=dfarea["Crop"]
y=dfarea['Area']
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
plt.grid()
plt.ylabel('Area')
plt.bar(x,y)
plt.show()

# %%
df['Production'].median()
# Out:
# np.float64(13804.0)

# %%
dfpw = df[(df['Crop'] == 'Wheat') & (df['Crop_Year'] == 2019)]
dfpw
# Out:
#         Crop  Crop_Year       Season              State        Area  \
# 18641  Wheat       2019  Rabi            Andhra Pradesh        37.0
# 18665  Wheat       2019  Rabi         Arunachal Pradesh      3930.0
# 18700  Wheat       2019  Rabi                     Assam     11336.0
# 18743  Wheat       2019  Rabi                     Bihar   2150180.0
# 18791  Wheat       2019  Rabi              Chhattisgarh    116274.0
# 18799  Wheat       2019  Rabi                     Delhi     19228.0
# 18853  Wheat       2019  Rabi                   Gujarat   1393487.0
# 18882  Wheat       2019  Rabi                   Haryana   2533800.0
# 18915  Wheat       2019  Rabi          Himachal Pradesh    319098.0
# 18954  Wheat       2019  Rabi         Jammu and Kashmir    243929.0
# 18981  Wheat       2019  Rabi                 Jharkhand    214780.0
# 19049  Wheat       2019  Rabi                 Karnataka    158319.0
# 19080  Wheat       2019  Whole Year              Kerala         1.0
# ...

# %%
dfpwf = dfpw[dfpw['Production'] > 1000000]
dfpwf
# Out:
#         Crop  Crop_Year       Season           State        Area  Production  \
# 18743  Wheat       2019  Rabi                  Bihar   2150180.0     5579348
# 18853  Wheat       2019  Rabi                Gujarat   1393487.0     4553681
# 18882  Wheat       2019  Rabi                Haryana   2533800.0    11876900
# 19118  Wheat       2019  Rabi         Madhya Pradesh  10216517.0    37507219
# 19154  Wheat       2019  Rabi            Maharashtra   1056965.0     1793440
# 19373  Wheat       2019  Rabi                 Punjab   3521000.0    17619000
# 19569  Wheat       2019  Rabi          Uttar Pradesh   9852504.0    36209665
#
#        Annual_Rainfall    Fertilizer   Pesticide     Yield
# 18743           1194.7  3.693149e+08   795566.60  2.569474
# 18853           1067.8  2.393453e+08   515590.19  3.143438
# 18882            351.8  4.352055e+08   937506.00  4.618182
# 19118           1446.7  1.754789e+09  3780111.29  3.519423
# ...

# %%
dfpwf.loc[dfpwf['State'] == 'Madhya Pradesh',  ]
plt.figure(figsize=(11,7))
plt.pie(dfpwf['Production'] , labels=dfpwf['State'] ,rotatelabels=True)
plt.title('Major Wheat Producing States in year 2019')
plt.show()
